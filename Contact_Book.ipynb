# %% [markdown]
# <a href="https://colab.research.google.com/github/chirustark17/CODSOFT/blob/main/Contact_Book.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Contact:
    def __init__(self, name, phone_number, email, address):
        self.name = name
        self.phone_number = phone_number
        self.email = email
        self.address = address

class ContactBook:
    def __init__(self):
        self.contacts = []

    def add_contact(self, contact):
        self.contacts.append(contact)

    def view_contacts(self):
        if not self.contacts:
            print("No contacts found.")
        else:
            for index, contact in enumerate(self.contacts, start=1):
                print(f"{index}. {contact.name}: {contact.phone_number}")

    def search_contacts(self, keyword):
        found_contacts = []
        for contact in self.contacts:
            if keyword.lower() in contact.name.lower() or keyword in contact.phone_number:
                found_contacts.append(contact)
        if found_contacts:
            for index, contact in enumerate(found_contacts, start=1):
                print(f"{index}. {contact.name}: {contact.phone_number}")
        else:
            print("No matching contacts found.")

    def update_contact(self, index, new_contact):
        self.contacts[index] = new_contact
        print("Contact updated successfully.")

    def delete_contact(self, index):
        del self.contacts[index]
        print("Contact deleted successfully.")

def display_menu():
    print("Welcome to the Contact Book!")
    print("1. Add Contact")
    print("2. View Contact List")
    print("3. Search Contact")
    print("4. Update Contact")
    print("5. Delete Contact")
    print("6. Exit")

def get_user_choice():
    while True:
        try:
            choice = int(input("Enter your choice: "))
            if choice < 1 or choice > 6:
                raise ValueError
            return choice
        except ValueError:
            print("Invalid choice. Please enter a number between 1 and 6.")

def get_contact_details():
    name = input("Enter name: ")
    phone_number = input("Enter phone number: ")
    email = input("Enter email: ")
    address = input("Enter address: ")
    return Contact(name, phone_number, email, address)

def main():
    contact_book = ContactBook()
    while True:
        display_menu()
        choice = get_user_choice()
        if choice == 1:  # Add Contact
            contact = get_contact_details()
            contact_book.add_contact(contact)
            print("Contact added successfully.")
        elif choice == 2:  # View Contact List
            contact_book.view_contacts()
        elif choice == 3:  # Search Contact
            keyword = input("Enter name or phone number to search: ")
            contact_book.search_contacts(keyword)
        elif choice == 4:  # Update Contact
            index = int(input("Enter index of contact to update: ")) - 1
            if 0 <= index < len(contact_book.contacts):
                new_contact = get_contact_details()
                contact_book.update_contact(index, new_contact)
            else:
                print("Invalid index.")
        elif choice == 5:  # Delete Contact
            index = int(input("Enter index of contact to delete: ")) - 1
            if 0 <= index < len(contact_book.contacts):
                contact_book.delete_contact(index)
            else:
                print("Invalid index.")
        elif choice == 6:  # Exit
            print("Thank you for using Contact Book. Goodbye!")
            break

if __name__ == "__main__":
    main()
# Out:
# Welcome to the Contact Book!
# 1. Add Contact
# 2. View Contact List
# 3. Search Contact
# 4. Update Contact
# 5. Delete Contact
# 6. Exit
# Enter your choice: 1
# Enter name: JOHN
# Enter phone number: 1234123412
# Enter email: john@gmail.com
# Enter address: 01,George street, Boston
# Contact added successfully.
# Welcome to the Contact Book!
# 1. Add Contact
# 2. View Contact List
# 3. Search Contact
# 4. Update Contact
# 5. Delete Contact
# 6. Exit
# Enter your choice: 1
# Enter name: BAKE
# Enter phone number: 9876987667
# Enter email: bakebakes@gmail.com
# Enter address: 22,lamp,shillong
# Contact added successfully.
# Welcome to the Contact Book!
# 1. Add Contact
# 2. View Contact List
# 3. Search Contact
# 4. Update Contact
# 5. Delete Contact
# 6. Exit
# Enter your choice: 2
# 1. JOHN: 1234123412
# 2. BAKE: 9876987667
# Welcome to the Contact Book!
# 1. Add Contact
# 2. View Contact List
# 3. Search Contact
# 4. Update Contact
# 5. Delete Contact
# 6. Exit
# Enter your choice: 3
# Enter name or phone number to search: bake
# Enter your choice: 4
# Enter index of contact to update: 1
# Enter name: johns
# Enter phone number: 1234123412
# Enter email: johns@gmail.com
# Enter address: 01,George street, Boston
# Contact updated successfully.
# Welcome to the Contact Book!
# 1. Add Contact
# 2. View Contact List
# 3. Search Contact
# 4. Update Contact
# 5. Delete Contact
# 6. Exit
# Enter your choice: 2
# 1. johns: 1234123412
# 2. BAKE: 9876987667
# Welcome to the Contact Book!
# 1. Add Contact
# 2. View Contact List
# 3. Search Contact
# 4. Update Contact
# 5. Delete Contact
# 6. Exit
# Enter your choice: 5
# Enter index of contact to delete: 2
# Contact deleted successfully.
# Welcome to the Contact Book!
# 1. Add Contact
# 2. View Contact List
# 3. Search Contact
# 4. Update Contact
# 5. Delete Contact
# 6. Exit
# Enter your choice: 2
# 1. johns: 1234123412
# Welcome to the Contact Book!
# 1. Add Contact
# 2. View Contact List
# 3. Search Contact
# 4. Update Contact
# 5. Delete Contact
# 6. Exit
# Enter your choice: 6
# Thank you for using Contact Book. Goodbye!
